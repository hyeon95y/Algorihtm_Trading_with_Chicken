# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import multiprocessing
from multiprocessing.pool import ThreadPool

import numpy as np
import pandas as pd
import datetime

import matplotlib.pyplot as plt
import tqdm
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
from data_io import load_data_by_ticker, get_call_data_for_given_ticker, display_all, display_shape, calls_amount

# %%
import matplotlib.font_manager as font_manager

font_dirs = ['/usr/share/fonts/truetype/nanum']
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
font_list = font_manager.createFontList(font_files)
font_manager.fontManager.ttflist.extend(font_list)

plt.rcParams['font.family'] = 'NanumGothic'

# %%
calls = pd.read_pickle('data/CALLS_TRANSFORMED.pkl')
calls[0:1]
# Out:
#             월   요일  평균기온  최고기온  최저기온  일강수량  평균풍속  최다풍향  평균상대습도  가조시간  ...  \
# 2013-08-01  8  목요일  28.0  24.5  32.1   0.0   1.7  50.0    67.3  14.1  ...
#
#             중랑구, 20대, 남  중랑구, 20대, 여  중랑구, 30대, 남  중랑구, 30대, 여  중랑구, 40대, 남  \
# 2013-08-01           79           91           98          133           62
#
#             중랑구, 40대, 여  중랑구, 50대, 남  중랑구, 50대, 여  중랑구, 60대, 남  중랑구, 60대, 여
# 2013-08-01           88         33.0           55          NaN          6.0
#
# [1 rows x 318 columns]

# %%
calls_original = pd.read_pickle('data/CALLS_CLIMATE.pkl')
calls_original[0:1]
# Out:
#           날짜  시군구 성별  연령대  총건수  월   요일  평균기온  최고기온  최저기온  ...  최다풍향  평균상대습도  \
# 0 2013-08-01  강남구  남  10대   71  8  목요일  28.0  24.5  32.1  ...  50.0    67.3
#
#    가조시간  일조시간  강설량  평균운량  미세먼지  공휴일_당일  공휴일_전날  일
# 0  14.1   6.0  0.0   7.1    34       0       0  1
#
# [1 rows x 22 columns]

# %%
calls_all = pd.read_pickle('data/CALLS_ALL_TRANSFORMED.pkl')
calls_all = calls_all.groupby(['업종', '일자'])['총건수'].sum()
calls_all = calls_all.to_frame().reset_index(drop=False)
calls_all.columns = ['날짜' if x=='일자' else x for x in calls_all.columns]
display(calls_all)
calls_all['업종'].unique()
# Out:
#            업종         날짜   총건수
# 0     족발/보쌈전문 2013-08-01  2989
# 1     족발/보쌈전문 2013-08-02  3389
# 2     족발/보쌈전문 2013-08-03  3935
# 3     족발/보쌈전문 2013-08-04  3682
# 4     족발/보쌈전문 2013-08-05  2645
# ...       ...        ...   ...
# 8883       피자 2019-08-27  3832
# 8884       피자 2019-08-28  3974
# 8885       피자 2019-08-29  4543
# 8886       피자 2019-08-30  5118
# 8887       피자 2019-08-31  5925
#
# [8888 rows x 3 columns]
# array(['족발/보쌈전문', '중국음식', '치킨', '피자'], dtype=object)

# %%
calls_all.shape
# Out:
# (8888, 3)

# %%
calls.index
# Out:
# DatetimeIndex(['2013-08-01', '2013-08-02', '2013-08-03', '2013-08-04',
#                '2013-08-05', '2013-08-06', '2013-08-07', '2013-08-08',
#                '2013-08-09', '2013-08-10',
#                ...
#                '2019-08-22', '2019-08-23', '2019-08-24', '2019-08-25',
#                '2019-08-26', '2019-08-27', '2019-08-28', '2019-08-29',
#                '2019-08-30', '2019-08-31'],
#               dtype='datetime64[ns]', length=2222, freq=None)

# %%
for food in calls_all['업종'].unique() :
    print(food)
    target = calls_all[calls_all['업종']==food]
    target.index = target['날짜']
    target = target.drop(['날짜', '업종'], axis=1)
    calls[food] = target['총건수']
    display(target)
# Out:
# 족발/보쌈전문
#              총건수
# 날짜
# 2013-08-01  2989
# 2013-08-02  3389
# 2013-08-03  3935
# 2013-08-04  3682
# 2013-08-05  2645
# ...          ...
# 2019-08-27  2359
# 2019-08-28  2341
# 2019-08-29  2612
# 2019-08-30  2959
# 2019-08-31  2876
#
# [2222 rows x 1 columns]
# 중국음식
#               총건수
# 날짜
# 2013-08-01  29310
# 2013-08-02  30199
# 2013-08-03  35965
# 2013-08-04  36219
# 2013-08-05  27561
# ...           ...
# 2019-08-27  10162
# 2019-08-28  10491
# 2019-08-29  14513
# 2019-08-30  11548
# 2019-08-31  13445
#
# [2222 rows x 1 columns]
# 치킨
#               총건수
# 날짜
# 2013-08-01  21906
# 2013-08-02  27457
# 2013-08-03  32984
# 2013-08-04  31856
# 2013-08-05  19661
# ...           ...
# 2019-08-27   8168
# 2019-08-28   8694
# 2019-08-29   9406
# 2019-08-30  12604
# 2019-08-31  13597
#
# [2222 rows x 1 columns]
# 피자
#               총건수
# 날짜
# 2013-08-01   6624
# 2013-08-02   8091
# 2013-08-03   9601
# 2013-08-04  10519
# 2013-08-05   6318
# ...           ...
# 2019-08-27   3832
# 2019-08-28   3974
# 2019-08-29   4543
# 2019-08-30   5118
# 2019-08-31   5925
#
# [2222 rows x 1 columns]

# %%
calls.to_pickle('data/CALLS_ALL_MERGED.pkl')

# %%
display(calls)
# Out:
#             월   요일  평균기온  최고기온  최저기온  일강수량  평균풍속   최다풍향  평균상대습도  가조시간  ...  \
# 2013-08-01  8  목요일  28.0  24.5  32.1   0.0   1.7   50.0    67.3  14.1  ...
# 2013-08-02  8  금요일  27.4  25.2  29.3   7.5   2.0   50.0    80.4  14.1  ...
# 2013-08-03  8  토요일  28.9  26.7  32.6   0.1   3.7  230.0    72.3  14.0  ...
# 2013-08-04  8  일요일  28.3  26.4  31.3   4.5   2.4  250.0    76.4  14.0  ...
# 2013-08-05  8  월요일  27.7  26.4  30.1   7.0   3.2  230.0    78.9  14.0  ...
# ...        ..  ...   ...   ...   ...   ...   ...    ...     ...   ...  ...
# 2019-08-27  8  화요일  25.7  22.2  29.3  20.0   1.0  290.0    71.1  13.2  ...
# 2019-08-28  8  수요일  26.1  23.6  30.2   0.0   1.9  270.0    66.2  13.2  ...
# 2019-08-29  8  목요일  23.4  20.1  26.4  36.9   2.2  160.0    77.1  13.1  ...
# 2019-08-30  8  금요일  22.6  19.5  27.0   0.2   2.4  200.0    66.3  13.1  ...
# 2019-08-31  8  토요일  23.5  18.5  28.9   0.0   1.9  230.0    65.0  13.1  ...
#
#             중랑구, 40대, 남  중랑구, 40대, 여  중랑구, 50대, 남  중랑구, 50대, 여  중랑구, 60대, 남  \
# 2013-08-01           62           88         33.0           55          NaN
# 2013-08-02           82          101         33.0           44         10.0
# 2013-08-03          108          136         36.0           48         17.0
# 2013-08-04           98          120         37.0           46         16.0
# 2013-08-05           56           65         30.0           28          8.0
# ...                 ...          ...          ...          ...          ...
# 2019-08-27           25           44         12.0            8          8.0
# 2019-08-28           20           39         17.0           21         10.0
# 2019-08-29           24           37          9.0           18         11.0
# 2019-08-30           37           51         14.0           25         10.0
# 2019-08-31           34           69         23.0           24         17.0
#
#             중랑구, 60대, 여  족발/보쌈전문   중국음식     치킨     피자
# 2013-08-01          6.0     2989  29310  21906   6624
# 2013-08-02         18.0     3389  30199  27457   8091
# 2013-08-03         19.0     3935  35965  32984   9601
# 2013-08-04         14.0     3682  36219  31856  10519
# 2013-08-05         12.0     2645  27561  19661   6318
# ...                 ...      ...    ...    ...    ...
# 2019-08-27         10.0     2359  10162   8168   3832
# 2019-08-28          5.0     2341  10491   8694   3974
# 2019-08-29         10.0     2612  14513   9406   4543
# 2019-08-30          8.0     2959  11548  12604   5118
# 2019-08-31         13.0     2876  13445  13597   5925
#
# [2222 rows x 322 columns]

# %%
kospi_downloaded = pd.read_pickle('history/kospi_download_result.pkl')
kospi_downloaded[0:1]
# Out:
#      종목코드        상장일     결과     기업명               업종
# 0  095570 2015-08-21  Naver  AJ네트웍스  산업용 기계 및 장비 임대업

# %%
kospi = pd.read_csv('metadata/kospi.csv', error_bad_lines=False)
kospi[0:1]
# Out:
# b'Skipping line 437: expected 12 fields, saw 13\n'
#   번호    종목코드     기업명      업종코드               업종    상장주식수(주)          자본금(원)  \
# 0  1  095570  AJ네트웍스  147603.0  산업용 기계 및 장비 임대업  46,822,295  46,822,295,000
#
#   액면가(원)    통화구분          대표전화                            주소   총카운트
# 0  1,000  원(KRW)  02-6363-9999  서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)  789.0

# %%
kosis_ecommerce_2013_2017 = pd.read_csv('data/kosis_ecommerce(201301-201712).csv', index_col=[0,1])
kosis_ecommerce_2013_2017 = kosis_ecommerce_2013_2017.reset_index(drop=False)
kosis_ecommerce_2013_2017['상품군별'] = kosis_ecommerce_2013_2017['상품군별'].fillna(method='ffill')
kosis_ecommerce_2013_2017['상품군별'] = kosis_ecommerce_2013_2017['상품군별'].apply(lambda x : x.replace('\u3000', '').replace(' ', ''))
display(kosis_ecommerce_2013_2017.T[kosis_ecommerce_2013_2017.T.columns[:3]])
# Out:
#                   0          1          2
# 상품군별             합계         합계         합계
# 판매매체별            합계      인터넷쇼핑      모바일쇼핑
# 2013. 01  3,189,033  2,815,624    373,409
# 2013. 02  2,752,824  2,405,536    347,288
# 2013. 03  3,033,675  2,626,963    406,712
# ...             ...        ...        ...
# 2017. 08  6,675,062  2,586,174  4,088,888
# 2017. 09  6,905,823  2,704,518  4,201,306
# 2017. 10  6,507,896  2,444,311  4,063,585
# 2017. 11  7,693,426  2,928,876  4,764,550
# 2017. 12  7,577,965  2,812,661  4,765,305
#
# [62 rows x 3 columns]

# %%
kosis_ecommerce_2017_2019 = pd.read_csv('data/kosis_ecommerce(201701-201909).csv', index_col=[0,1])
kosis_ecommerce_2017_2019 = kosis_ecommerce_2017_2019.reset_index(drop=False)
kosis_ecommerce_2017_2019['상품군별'] = kosis_ecommerce_2017_2019['상품군별'].fillna(method='ffill')
kosis_ecommerce_2017_2019['상품군별'] = kosis_ecommerce_2017_2019['상품군별'].apply(lambda x : x.replace(' ', ''))
kosis_ecommerce_2017_2019['판매매체별'] = kosis_ecommerce_2017_2019['판매매체별'].apply(lambda x : '합계' if x=='계' else x)
display(kosis_ecommerce_2017_2019.T[kosis_ecommerce_2017_2019.T.columns[:3]])
# Out:
#                       0          1          2
# 상품군별                 합계         합계         합계
# 판매매체별                합계      인터넷쇼핑      모바일쇼핑
# 2017. 01      7,310,479  3,390,183  3,920,295
# 2017. 02      7,148,849  3,298,823  3,850,025
# 2017. 03      7,747,011  3,585,449  4,161,562
# 2017. 04      7,380,795  3,304,819  4,075,976
# 2017. 05      7,621,719  3,359,693  4,262,026
# 2017. 06      7,515,130  3,341,138  4,173,992
# 2017. 07      7,898,554  3,404,599  4,493,955
# 2017. 08      7,859,658  3,395,357  4,464,301
# 2017. 09      8,151,143  3,585,077  4,566,066
# 2017. 10      7,661,802  3,247,093  4,414,710
# 2017. 11      8,996,978  3,781,198  5,215,779
# 2017. 12      8,893,647  3,582,993  5,310,654
# 2018. 01      9,076,322  3,739,332  5,336,990
# 2018. 02      8,241,284  3,337,074  4,904,210
# 2018. 03      9,436,142  3,926,602  5,509,540
# 2018. 04      9,079,855  3,677,952  5,401,903
# 2018. 05      9,405,150  3,731,359  5,673,791
# 2018. 06      9,012,646  3,559,823  5,452,823
# 2018. 07      9,692,619  3,754,123  5,938,496
# 2018. 08      9,271,640  3,513,822  5,757,818
# 2018. 09      9,139,296  3,544,481  5,594,815
# 2018. 10     10,062,838  3,830,732  6,232,106
# 2018. 11     10,611,411  4,046,629  6,564,782
# 2018. 12     10,700,489  3,972,797  6,727,693
# 2019. 01     10,682,707  3,912,176  6,770,531
# 2019. 02      9,561,182  3,394,829  6,166,352
# 2019. 03     11,220,212  4,159,150  7,061,062
# 2019. 04     10,623,611  3,937,626  6,685,985
# 2019. 05     11,232,072  4,078,119  7,153,953
# 2019. 06     10,557,017  3,702,233  6,854,783
# 2019. 07     11,185,384  3,967,022  7,218,362
# 2019. 08 p)  11,190,709  3,943,856  7,246,854
# 2019. 09 p)  11,179,724  3,952,075  7,227,648

# %%
print(kosis_ecommerce_2013_2017['상품군별'].unique())
display_all(kosis_ecommerce_2013_2017[['상품군별', '판매매체별']])
# Out:
# ['합계' '컴퓨터및주변기기' '가전·전자·통신기기' '소프트웨어' '서적' '사무·문구' '음반·비디오·악기'
#  '의류·패션및관련상품' '의복' '신발' '가방' '패션용품및악세사리' '스포츠·레저용품' '화장품' '아동·유아용품'
#  '음·식료품' '농축수산물' '생활·자동차용품' '가구' '꽃' '여행및예약서비스' '각종서비스' '기타' '애완용품']
#           상품군별  판매매체별
# 0           합계     합계
# 1           합계  인터넷쇼핑
# 2           합계  모바일쇼핑
# 3     컴퓨터및주변기기     합계
# 4     컴퓨터및주변기기  인터넷쇼핑
# 5     컴퓨터및주변기기  모바일쇼핑
# 6   가전·전자·통신기기     합계
# 7   가전·전자·통신기기  인터넷쇼핑
# 8   가전·전자·통신기기  모바일쇼핑
# 9        소프트웨어     합계
# 10       소프트웨어  인터넷쇼핑
# 11       소프트웨어  모바일쇼핑
# 12          서적     합계
# 13          서적  인터넷쇼핑
# 14          서적  모바일쇼핑
# 15       사무·문구     합계
# 16       사무·문구  인터넷쇼핑
# 17       사무·문구  모바일쇼핑
# 18   음반·비디오·악기     합계
# 19   음반·비디오·악기  인터넷쇼핑
# 20   음반·비디오·악기  모바일쇼핑
# 21  의류·패션및관련상품     합계
# 22  의류·패션및관련상품  인터넷쇼핑
# 23  의류·패션및관련상품  모바일쇼핑
# 24          의복     합계
# 25          의복  인터넷쇼핑
# 26          의복  모바일쇼핑
# 27          신발     합계
# 28          신발  인터넷쇼핑
# 29          신발  모바일쇼핑
# 30          가방     합계
# 31          가방  인터넷쇼핑
# 32          가방  모바일쇼핑
# 33   패션용품및악세사리     합계
# 34   패션용품및악세사리  인터넷쇼핑
# 35   패션용품및악세사리  모바일쇼핑
# 36    스포츠·레저용품     합계
# 37    스포츠·레저용품  인터넷쇼핑
# 38    스포츠·레저용품  모바일쇼핑
# 39         화장품     합계
# 40         화장품  인터넷쇼핑
# 41         화장품  모바일쇼핑
# 42     아동·유아용품     합계
# 43     아동·유아용품  인터넷쇼핑
# 44     아동·유아용품  모바일쇼핑
# 45       음·식료품     합계
# 46       음·식료품  인터넷쇼핑
# 47       음·식료품  모바일쇼핑
# 48       농축수산물     합계
# 49       농축수산물  인터넷쇼핑
# 50       농축수산물  모바일쇼핑
# 51    생활·자동차용품     합계
# 52    생활·자동차용품  인터넷쇼핑
# 53    생활·자동차용품  모바일쇼핑
# 54    생활·자동차용품     합계
# 55    생활·자동차용품  인터넷쇼핑
# 56    생활·자동차용품  모바일쇼핑
# 57          가구     합계
# 58          가구  인터넷쇼핑
# 59          가구  모바일쇼핑
# 60           꽃     합계
# 61           꽃  인터넷쇼핑
# 62           꽃  모바일쇼핑
# 63    여행및예약서비스     합계
# 64    여행및예약서비스  인터넷쇼핑
# 65    여행및예약서비스  모바일쇼핑
# 66       각종서비스     합계
# 67       각종서비스  인터넷쇼핑
# 68       각종서비스  모바일쇼핑
# 69          기타     합계
# 70          기타  인터넷쇼핑
# 71          기타  모바일쇼핑
# 72          기타     합계
# 73          기타  인터넷쇼핑
# 74          기타  모바일쇼핑
# 75        애완용품     합계
# 76        애완용품  인터넷쇼핑
# 77        애완용품  모바일쇼핑

# %%
print(kosis_ecommerce_2017_2019['상품군별'].unique())
display_all(kosis_ecommerce_2017_2019[['상품군별', '판매매체별']])
# Out:
# ['합계' '컴퓨터 및 주변기기' '가전·전자·통신기기' '서적' '사무·문구' '의복' '신발' '가방' '패션용품 및 액세서리'
#  '스포츠·레저용품' '화장품' '아동·유아용품' '음·식료품' '농축수산물' '생활용품' '자동차용품' '가구' '애완용품'
#  '여행 및 교통서비스' '문화 및 레저서비스' 'e쿠폰서비스' '음식서비스' '기타서비스' '기타']
#            상품군별  판매매체별
# 0            합계     합계
# 1            합계  인터넷쇼핑
# 2            합계  모바일쇼핑
# 3    컴퓨터 및 주변기기     합계
# 4    컴퓨터 및 주변기기  인터넷쇼핑
# 5    컴퓨터 및 주변기기  모바일쇼핑
# 6    가전·전자·통신기기     합계
# 7    가전·전자·통신기기  인터넷쇼핑
# 8    가전·전자·통신기기  모바일쇼핑
# 9            서적     합계
# 10           서적  인터넷쇼핑
# 11           서적  모바일쇼핑
# 12        사무·문구     합계
# 13        사무·문구  인터넷쇼핑
# 14        사무·문구  모바일쇼핑
# 15           의복     합계
# 16           의복  인터넷쇼핑
# 17           의복  모바일쇼핑
# 18           신발     합계
# 19           신발  인터넷쇼핑
# 20           신발  모바일쇼핑
# 21           가방     합계
# 22           가방  인터넷쇼핑
# 23           가방  모바일쇼핑
# 24  패션용품 및 액세서리     합계
# 25  패션용품 및 액세서리  인터넷쇼핑
# 26  패션용품 및 액세서리  모바일쇼핑
# 27     스포츠·레저용품     합계
# 28     스포츠·레저용품  인터넷쇼핑
# 29     스포츠·레저용품  모바일쇼핑
# 30          화장품     합계
# 31          화장품  인터넷쇼핑
# 32          화장품  모바일쇼핑
# 33      아동·유아용품     합계
# 34      아동·유아용품  인터넷쇼핑
# 35      아동·유아용품  모바일쇼핑
# 36        음·식료품     합계
# 37        음·식료품  인터넷쇼핑
# 38        음·식료품  모바일쇼핑
# 39        농축수산물     합계
# 40        농축수산물  인터넷쇼핑
# 41        농축수산물  모바일쇼핑
# 42         생활용품     합계
# 43         생활용품  인터넷쇼핑
# 44         생활용품  모바일쇼핑
# 45        자동차용품     합계
# 46        자동차용품  인터넷쇼핑
# 47        자동차용품  모바일쇼핑
# 48           가구     합계
# 49           가구  인터넷쇼핑
# 50           가구  모바일쇼핑
# 51         애완용품     합계
# 52         애완용품  인터넷쇼핑
# 53         애완용품  모바일쇼핑
# 54   여행 및 교통서비스     합계
# 55   여행 및 교통서비스  인터넷쇼핑
# 56   여행 및 교통서비스  모바일쇼핑
# 57   문화 및 레저서비스     합계
# 58   문화 및 레저서비스  인터넷쇼핑
# 59   문화 및 레저서비스  모바일쇼핑
# 60       e쿠폰서비스     합계
# 61       e쿠폰서비스  인터넷쇼핑
# 62       e쿠폰서비스  모바일쇼핑
# 63        음식서비스     합계
# 64        음식서비스  인터넷쇼핑
# 65        음식서비스  모바일쇼핑
# 66        기타서비스     합계
# 67        기타서비스  인터넷쇼핑
# 68        기타서비스  모바일쇼핑
# 69           기타     합계
# 70           기타  인터넷쇼핑
# 71           기타  모바일쇼핑

# %%
temp_2013 = kosis_ecommerce_2013_2017.T[kosis_ecommerce_2013_2017.T.columns[:3]]
temp_2017 = kosis_ecommerce_2017_2019.T[kosis_ecommerce_2017_2019.T.columns[:3]]

# %%
temp_2013.columns = ['합계', '인터넷쇼핑', '모바일쇼핑']
temp_2017.columns = ['합계', '인터넷쇼핑', '모바일쇼핑']
temp = pd.concat([temp_2013.iloc[2:], temp_2017.iloc[2:]], ignore_index=False)
temp.index = [x.replace(' p)', '') for x in temp.index]
temp.index = pd.to_datetime(temp.index)
temp.to_pickle('kosis_ecommerce_all.pkl')
temp
# Out:
#                     합계      인터넷쇼핑      모바일쇼핑
# 2013-01-01   3,189,033  2,815,624    373,409
# 2013-02-01   2,752,824  2,405,536    347,288
# 2013-03-01   3,033,675  2,626,963    406,712
# 2013-04-01   3,014,762  2,606,326    408,436
# 2013-05-01   3,170,619  2,718,382    452,237
# ...                ...        ...        ...
# 2019-05-01  11,232,072  4,078,119  7,153,953
# 2019-06-01  10,557,017  3,702,233  6,854,783
# 2019-07-01  11,185,384  3,967,022  7,218,362
# 2019-08-01  11,190,709  3,943,856  7,246,854
# 2019-09-01  11,179,724  3,952,075  7,227,648
#
# [93 rows x 3 columns]

# %%
calls_all_merged = pd.read_pickle('data/CALLS_ALL_MERGED.pkl')
calls_all_merged
# Out:
#             월   요일  평균기온  최고기온  최저기온  일강수량  평균풍속   최다풍향  평균상대습도  가조시간  ...  \
# 2013-08-01  8  목요일  28.0  24.5  32.1   0.0   1.7   50.0    67.3  14.1  ...
# 2013-08-02  8  금요일  27.4  25.2  29.3   7.5   2.0   50.0    80.4  14.1  ...
# 2013-08-03  8  토요일  28.9  26.7  32.6   0.1   3.7  230.0    72.3  14.0  ...
# 2013-08-04  8  일요일  28.3  26.4  31.3   4.5   2.4  250.0    76.4  14.0  ...
# 2013-08-05  8  월요일  27.7  26.4  30.1   7.0   3.2  230.0    78.9  14.0  ...
# ...        ..  ...   ...   ...   ...   ...   ...    ...     ...   ...  ...
# 2019-08-27  8  화요일  25.7  22.2  29.3  20.0   1.0  290.0    71.1  13.2  ...
# 2019-08-28  8  수요일  26.1  23.6  30.2   0.0   1.9  270.0    66.2  13.2  ...
# 2019-08-29  8  목요일  23.4  20.1  26.4  36.9   2.2  160.0    77.1  13.1  ...
# 2019-08-30  8  금요일  22.6  19.5  27.0   0.2   2.4  200.0    66.3  13.1  ...
# 2019-08-31  8  토요일  23.5  18.5  28.9   0.0   1.9  230.0    65.0  13.1  ...
#
#             중랑구, 40대, 남  중랑구, 40대, 여  중랑구, 50대, 남  중랑구, 50대, 여  중랑구, 60대, 남  \
# 2013-08-01           62           88         33.0           55          NaN
# 2013-08-02           82          101         33.0           44         10.0
# 2013-08-03          108          136         36.0           48         17.0
# 2013-08-04           98          120         37.0           46         16.0
# 2013-08-05           56           65         30.0           28          8.0
# ...                 ...          ...          ...          ...          ...
# 2019-08-27           25           44         12.0            8          8.0
# 2019-08-28           20           39         17.0           21         10.0
# 2019-08-29           24           37          9.0           18         11.0
# 2019-08-30           37           51         14.0           25         10.0
# 2019-08-31           34           69         23.0           24         17.0
#
#             중랑구, 60대, 여  족발/보쌈전문   중국음식     치킨     피자
# 2013-08-01          6.0     2989  29310  21906   6624
# 2013-08-02         18.0     3389  30199  27457   8091
# 2013-08-03         19.0     3935  35965  32984   9601
# 2013-08-04         14.0     3682  36219  31856  10519
# 2013-08-05         12.0     2645  27561  19661   6318
# ...                 ...      ...    ...    ...    ...
# 2019-08-27         10.0     2359  10162   8168   3832
# 2019-08-28          5.0     2341  10491   8694   3974
# 2019-08-29         10.0     2612  14513   9406   4543
# 2019-08-30          8.0     2959  11548  12604   5118
# 2019-08-31         13.0     2876  13445  13597   5925
#
# [2222 rows x 322 columns]

# %%
temp
# Out:
#                     합계      인터넷쇼핑      모바일쇼핑
# 2013-01-01   3,189,033  2,815,624    373,409
# 2013-02-01   2,752,824  2,405,536    347,288
# 2013-03-01   3,033,675  2,626,963    406,712
# 2013-04-01   3,014,762  2,606,326    408,436
# 2013-05-01   3,170,619  2,718,382    452,237
# ...                ...        ...        ...
# 2019-05-01  11,232,072  4,078,119  7,153,953
# 2019-06-01  10,557,017  3,702,233  6,854,783
# 2019-07-01  11,185,384  3,967,022  7,218,362
# 2019-08-01  11,190,709  3,943,856  7,246,854
# 2019-09-01  11,179,724  3,952,075  7,227,648
#
# [93 rows x 3 columns]

# %%
merge_test = calls_all_merged.merge(temp, how='outer', left_on=calls_all_merged.index, right_on=temp.index)
merge_test = merge_test[merge_test['월'].notnull()]
merge_test.index = merge_test['key_0']
merge_test = merge_test.drop(['key_0'], axis=1)
for column in temp.columns : 
    merge_test[column] = merge_test[column].fillna(method='ffill')

merge_test
# Out:
#               월   요일  평균기온  최고기온  최저기온  일강수량  평균풍속   최다풍향  평균상대습도  가조시간  ...  \
# key_0                                                                    ...
# 2013-08-01  8.0  목요일  28.0  24.5  32.1   0.0   1.7   50.0    67.3  14.1  ...
# 2013-08-02  8.0  금요일  27.4  25.2  29.3   7.5   2.0   50.0    80.4  14.1  ...
# 2013-08-03  8.0  토요일  28.9  26.7  32.6   0.1   3.7  230.0    72.3  14.0  ...
# 2013-08-04  8.0  일요일  28.3  26.4  31.3   4.5   2.4  250.0    76.4  14.0  ...
# 2013-08-05  8.0  월요일  27.7  26.4  30.1   7.0   3.2  230.0    78.9  14.0  ...
# ...         ...  ...   ...   ...   ...   ...   ...    ...     ...   ...  ...
# 2019-08-27  8.0  화요일  25.7  22.2  29.3  20.0   1.0  290.0    71.1  13.2  ...
# 2019-08-28  8.0  수요일  26.1  23.6  30.2   0.0   1.9  270.0    66.2  13.2  ...
# 2019-08-29  8.0  목요일  23.4  20.1  26.4  36.9   2.2  160.0    77.1  13.1  ...
# 2019-08-30  8.0  금요일  22.6  19.5  27.0   0.2   2.4  200.0    66.3  13.1  ...
# 2019-08-31  8.0  토요일  23.5  18.5  28.9   0.0   1.9  230.0    65.0  13.1  ...
#
#             중랑구, 50대, 여  중랑구, 60대, 남  중랑구, 60대, 여  족발/보쌈전문     중국음식       치킨  \
# key_0
# 2013-08-01         55.0          NaN          6.0   2989.0  29310.0  21906.0
# 2013-08-02         44.0         10.0         18.0   3389.0  30199.0  27457.0
# 2013-08-03         48.0         17.0         19.0   3935.0  35965.0  32984.0
# 2013-08-04         46.0         16.0         14.0   3682.0  36219.0  31856.0
# 2013-08-05         28.0          8.0         12.0   2645.0  27561.0  19661.0
# ...                 ...          ...          ...      ...      ...      ...
# 2019-08-27          8.0          8.0         10.0   2359.0  10162.0   8168.0
# 2019-08-28         21.0         10.0          5.0   2341.0  10491.0   8694.0
# 2019-08-29         18.0         11.0         10.0   2612.0  14513.0   9406.0
# 2019-08-30         25.0         10.0          8.0   2959.0  11548.0  12604.0
# 2019-08-31         24.0         17.0         13.0   2876.0  13445.0  13597.0
#
#                  피자          합계      인터넷쇼핑      모바일쇼핑
# key_0
# 2013-08-01   6624.0   3,162,920  2,582,185    580,735
# 2013-08-02   8091.0   3,162,920  2,582,185    580,735
# 2013-08-03   9601.0   3,162,920  2,582,185    580,735
# 2013-08-04  10519.0   3,162,920  2,582,185    580,735
# 2013-08-05   6318.0   3,162,920  2,582,185    580,735
# ...             ...         ...        ...        ...
# 2019-08-27   3832.0  11,190,709  3,943,856  7,246,854
# 2019-08-28   3974.0  11,190,709  3,943,856  7,246,854
# 2019-08-29   4543.0  11,190,709  3,943,856  7,246,854
# 2019-08-30   5118.0  11,190,709  3,943,856  7,246,854
# 2019-08-31   5925.0  11,190,709  3,943,856  7,246,854
#
# [2234 rows x 325 columns]

# %%
merge_test
# Out:
#               월   요일  평균기온  최고기온  최저기온  일강수량  평균풍속   최다풍향  평균상대습도  가조시간  ...  \
# key_0                                                                    ...
# 2013-08-01  8.0  목요일  28.0  24.5  32.1   0.0   1.7   50.0    67.3  14.1  ...
# 2013-08-02  8.0  금요일  27.4  25.2  29.3   7.5   2.0   50.0    80.4  14.1  ...
# 2013-08-03  8.0  토요일  28.9  26.7  32.6   0.1   3.7  230.0    72.3  14.0  ...
# 2013-08-04  8.0  일요일  28.3  26.4  31.3   4.5   2.4  250.0    76.4  14.0  ...
# 2013-08-05  8.0  월요일  27.7  26.4  30.1   7.0   3.2  230.0    78.9  14.0  ...
# ...         ...  ...   ...   ...   ...   ...   ...    ...     ...   ...  ...
# 2019-08-27  8.0  화요일  25.7  22.2  29.3  20.0   1.0  290.0    71.1  13.2  ...
# 2019-08-28  8.0  수요일  26.1  23.6  30.2   0.0   1.9  270.0    66.2  13.2  ...
# 2019-08-29  8.0  목요일  23.4  20.1  26.4  36.9   2.2  160.0    77.1  13.1  ...
# 2019-08-30  8.0  금요일  22.6  19.5  27.0   0.2   2.4  200.0    66.3  13.1  ...
# 2019-08-31  8.0  토요일  23.5  18.5  28.9   0.0   1.9  230.0    65.0  13.1  ...
#
#             중랑구, 50대, 여  중랑구, 60대, 남  중랑구, 60대, 여  족발/보쌈전문     중국음식       치킨  \
# key_0
# 2013-08-01         55.0          NaN          6.0   2989.0  29310.0  21906.0
# 2013-08-02         44.0         10.0         18.0   3389.0  30199.0  27457.0
# 2013-08-03         48.0         17.0         19.0   3935.0  35965.0  32984.0
# 2013-08-04         46.0         16.0         14.0   3682.0  36219.0  31856.0
# 2013-08-05         28.0          8.0         12.0   2645.0  27561.0  19661.0
# ...                 ...          ...          ...      ...      ...      ...
# 2019-08-27          8.0          8.0         10.0   2359.0  10162.0   8168.0
# 2019-08-28         21.0         10.0          5.0   2341.0  10491.0   8694.0
# 2019-08-29         18.0         11.0         10.0   2612.0  14513.0   9406.0
# 2019-08-30         25.0         10.0          8.0   2959.0  11548.0  12604.0
# 2019-08-31         24.0         17.0         13.0   2876.0  13445.0  13597.0
#
#                  피자          합계      인터넷쇼핑      모바일쇼핑
# key_0
# 2013-08-01   6624.0   3,162,920  2,582,185    580,735
# 2013-08-02   8091.0   3,162,920  2,582,185    580,735
# 2013-08-03   9601.0   3,162,920  2,582,185    580,735
# 2013-08-04  10519.0   3,162,920  2,582,185    580,735
# 2013-08-05   6318.0   3,162,920  2,582,185    580,735
# ...             ...         ...        ...        ...
# 2019-08-27   3832.0  11,190,709  3,943,856  7,246,854
# 2019-08-28   3974.0  11,190,709  3,943,856  7,246,854
# 2019-08-29   4543.0  11,190,709  3,943,856  7,246,854
# 2019-08-30   5118.0  11,190,709  3,943,856  7,246,854
# 2019-08-31   5925.0  11,190,709  3,943,856  7,246,854
#
# [2234 rows x 325 columns]

# %%
merge_test.to_pickle('data/CALLS_FINAL.pkl')

# %%
merge_test.to_csv('data/CALLS_FINAL.csv')
