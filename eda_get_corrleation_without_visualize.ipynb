# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import multiprocessing
from multiprocessing.pool import ThreadPool

import numpy as np
import pandas as pd
import datetime

import matplotlib.pyplot as plt
import tqdm
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
from data_io import load_data_by_ticker, get_call_data_for_given_ticker, display_all, calls_amount

# %% [markdown]
# # Load Data

# %%
calls = pd.read_pickle('data/CALLS_TRANSFORMED.pkl')
kospi_downloaded = pd.read_pickle('history/kospi_download_result.pkl')
kospi = pd.read_csv('metadata/kospi.csv', error_bad_lines=False)
# Out:
# b'Skipping line 437: expected 12 fields, saw 13\n'

# %%
tickers = kospi_downloaded['종목코드']

# %%
_, columns_for_df = get_call_data_for_given_ticker(calls, kospi, tickers[0])
columns_for_df = columns_for_df.columns.insert(0, 'Time lag').insert(0, 'Correlation with').insert(0, 'ticker').insert(0, '기업명')
df_corr = pd.DataFrame(columns=columns_for_df)
df_corr
# Out:
# Empty DataFrame
# Columns: [기업명, ticker, Correlation with, Time lag, High, Low, Open, Close, Volume, Adj Close, 총건수, 강남구, 10대, 남, 강남구, 10대, 여, 강남구, 20대, 남, 강남구, 20대, 여, 강남구, 30대, 남, 강남구, 30대, 여, 강남구, 40대, 남, 강남구, 40대, 여, 강남구, 50대, 남, 강남구, 50대, 여, 강남구, 60대, 남, 강남구, 60대, 여, 강동구, 10대, 남, 강동구, 10대, 여, 강동구, 20대, 남, 강동구, 20대, 여, 강동구, 30대, 남, 강동구, 30대, 여, 강동구, 40대, 남, 강동구, 40대, 여, 강동구, 50대, 남, 강동구, 50대, 여, 강동구, 60대, 남, 강동구, 60대, 여, 강북구, 10대, 남, 강북구, 10대, 여, 강북구, 20대, 남, 강북구, 20대, 여, 강북구, 30대, 남, 강북구, 30대, 여, 강북구, 40대, 남, 강북구, 40대, 여, 강북구, 50대, 남, 강북구, 50대, 여, 강북구, 60대, 남, 강북구, 60대, 여, 강서구, 10대, 남, 강서구, 10대, 여, 강서구, 20대, 남, 강서구, 20대, 여, 강서구, 30대, 남, 강서구, 30대, 여, 강서구, 40대, 남, 강서구, 40대, 여, 강서구, 50대, 남, 강서구, 50대, 여, 강서구, 60대, 남, 강서구, 60대, 여, 관악구, 10대, 남, 관악구, 10대, 여, 관악구, 20대, 남, 관악구, 20대, 여, 관악구, 30대, 남, 관악구, 30대, 여, 관악구, 40대, 남, 관악구, 40대, 여, 관악구, 50대, 남, 관악구, 50대, 여, 관악구, 60대, 남, 관악구, 60대, 여, 광진구, 10대, 남, 광진구, 10대, 여, 광진구, 20대, 남, 광진구, 20대, 여, 광진구, 30대, 남, 광진구, 30대, 여, 광진구, 40대, 남, 광진구, 40대, 여, 광진구, 50대, 남, 광진구, 50대, 여, 광진구, 60대, 남, 광진구, 60대, 여, 구로구, 10대, 남, 구로구, 10대, 여, 구로구, 20대, 남, 구로구, 20대, 여, 구로구, 30대, 남, 구로구, 30대, 여, 구로구, 40대, 남, 구로구, 40대, 여, 구로구, 50대, 남, 구로구, 50대, 여, 구로구, 60대, 남, 구로구, 60대, 여, 금천구, 10대, 남, 금천구, 10대, 여, 금천구, 20대, 남, 금천구, 20대, 여, 금천구, 30대, 남, ...]
# Index: []
#
# [0 rows x 311 columns]

# %% [markdown]
# # Get Correlation

# %%
def get_correlation_by_ticker(calls, kospi, ticker, idx) : 

    company_name, df_totest = get_call_data_for_given_ticker(calls, kospi, ticker)
    
    
    time_lags = [0,1,2,5,10,25,50]
    
    # for time lag
    for idx_time_lag, time_lag in enumerate(time_lags) : 
        df = df_totest.copy()
        if time_lag != 0 :
            df[['High', 'Low', 'Open', 'Close', 'Volume']] = df[['High', 'Low', 'Open', 'Close', 'Volume']].shift(periods=time_lag*(-1))
        
        # for price and volume
        candidates = ['High', 'Low', 'Open', 'Close', 'Volume']
        for idx_candidate, candidate in enumerate(candidates) : 
            temp = df.corr()[candidate]
            temp = pd.concat([pd.Series([company_name, ticker, candidate, time_lag], index=['기업명', 'ticker', 'Correlation with', 'Time lag']), temp])
            df_corr.loc[idx*(len(time_lags)*len(candidates))+idx_time_lag*len(candidates)+idx_candidate] = temp

    pbar.update(1)
    return

#idx = 0
#get_correlation_by_ticker(calls, kospi, tickers[idx], idx)
#df_corr.head()

# %%
pool = ThreadPool(24)
with tqdm.tqdm(total=tickers.shape[0]) as pbar :
    for idx in range(tickers.shape[0]) : 
        pool.apply_async(get_correlation_by_ticker, [calls, kospi, tickers[idx], idx])
        
    pool.close()
    pool.join()
    
df_corr.to_pickle('metadata/df_corr.pkl')
# Out:
#  54%|█████▍    | 428/788 [41:11<34:38,  5.77s/it]

# %%
kospi.head()
# Out:
#   번호    종목코드     기업명      업종코드               업종    상장주식수(주)          자본금(원)  \
# 0  1  095570  AJ네트웍스  147603.0  산업용 기계 및 장비 임대업  46,822,295  46,822,295,000
# 1  2  068400   AJ렌터카  147601.0         운송장비 임대업  22,146,300  11,073,150,000
# 2  3  006840   AK홀딩스  116409.0           기타 금융업  13,247,561  66,237,805,000
# 3  4  027410     BGF  116409.0           기타 금융업  95,716,791  95,716,791,000
# 4  5  282330  BGF리테일   74701.0           종합 소매업  17,283,906  17,283,906,000
#
#   액면가(원)    통화구분          대표전화                            주소   총카운트
# 0  1,000  원(KRW)  02-6363-9999  서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)  789.0
# 1    500  원(KRW)     1544-1600          서울특별시 구로구  서부샛길 822   789.0
# 2  5,000  원(KRW)   02-768-2923          서울특별시 마포구 양화로 188 -   789.0
# 3  1,000     NaN     1577-3663           서울특별시 강남구 테헤란로 405   789.0
# 4  1,000  원(KRW)  02-1577-8007      서울특별시 강남구 테헤란로 405 BGF사옥  789.0

# %% [markdown]
# # Correlation Matrix

# %%
df_corr_original = pd.read_pickle('metadata/df_corr.pkl')
df_corr = df_corr_original.copy()
df_corr = df_corr.drop(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], axis=1)
df_corr = df_corr.sort_index()

def get_company_sector(ticker) : 
    df = kospi[kospi['종목코드']==ticker]
    return df['업종'].values[0]

df_corr['업종'] = df_corr['ticker'].apply(lambda x : get_company_sector(x))

print('df_corr.shape : ', df_corr.shape)
print("df_corr['기업명'].unique().shape : ", df_corr['기업명'].unique().shape)
display(df_corr.head())
# Out:
# df_corr.shape :  (10461, 306)
# df_corr['기업명'].unique().shape :  (773,)
#       기업명  ticker Correlation with Time lag       총건수  강남구, 10대, 남  \
# 0  AJ네트웍스  095570             High        0  0.286720     0.059425
# 1  AJ네트웍스  095570              Low        0  0.288794     0.063129
# 3  AJ네트웍스  095570            Close        0  0.351568     0.132500
# 4  AJ네트웍스  095570           Volume        0  0.014660     0.058940
# 5  AJ네트웍스  095570             High        1  0.285336     0.051969
#
#    강남구, 10대, 여  강남구, 20대, 남  강남구, 20대, 여  강남구, 30대, 남  ...  중랑구, 20대, 여  \
# 0     0.030947     0.432957     0.490182     0.318886  ...     0.414426
# 1     0.039238     0.430153     0.482587     0.318194  ...     0.405722
# 3     0.107238     0.537662     0.579584     0.364488  ...     0.499572
# 4     0.056624    -0.048749    -0.045125    -0.014240  ...     0.006909
# 5     0.030900     0.427200     0.483351     0.315640  ...     0.414774
#
#    중랑구, 30대, 남  중랑구, 30대, 여  중랑구, 40대, 남  중랑구, 40대, 여  중랑구, 50대, 남  \
# 0     0.353341     0.402528     0.137330     0.099658     0.021042
# 1     0.351589     0.398827     0.141923     0.104124     0.026743
# 3     0.424915     0.470909     0.152728     0.130431     0.040273
# 4     0.037490     0.012440     0.037910     0.042405    -0.019231
# 5     0.354010     0.403931     0.136317     0.094650     0.029805
#
#    중랑구, 50대, 여  중랑구, 60대, 남  중랑구, 60대, 여               업종
# 0     0.032105    -0.140410    -0.100652  산업용 기계 및 장비 임대업
# 1     0.040405    -0.136346    -0.097204  산업용 기계 및 장비 임대업
# 3     0.031837    -0.113930    -0.067042  산업용 기계 및 장비 임대업
# 4     0.049486     0.023700     0.060874  산업용 기계 및 장비 임대업
# 5     0.027707    -0.142246    -0.096205  산업용 기계 및 장비 임대업
#
# [5 rows x 306 columns]

# %% [markdown]
# # Mean correlation per sector

# %%
df_corr.head()
# Out:
#       기업명  ticker Correlation with Time lag       총건수  강남구, 10대, 남  \
# 0  AJ네트웍스  095570             High        0  0.286720     0.059425
# 1  AJ네트웍스  095570              Low        0  0.288794     0.063129
# 3  AJ네트웍스  095570            Close        0  0.351568     0.132500
# 4  AJ네트웍스  095570           Volume        0  0.014660     0.058940
# 5  AJ네트웍스  095570             High        1  0.285336     0.051969
#
#    강남구, 10대, 여  강남구, 20대, 남  강남구, 20대, 여  강남구, 30대, 남  ...  중랑구, 20대, 여  \
# 0     0.030947     0.432957     0.490182     0.318886  ...     0.414426
# 1     0.039238     0.430153     0.482587     0.318194  ...     0.405722
# 3     0.107238     0.537662     0.579584     0.364488  ...     0.499572
# 4     0.056624    -0.048749    -0.045125    -0.014240  ...     0.006909
# 5     0.030900     0.427200     0.483351     0.315640  ...     0.414774
#
#    중랑구, 30대, 남  중랑구, 30대, 여  중랑구, 40대, 남  중랑구, 40대, 여  중랑구, 50대, 남  \
# 0     0.353341     0.402528     0.137330     0.099658     0.021042
# 1     0.351589     0.398827     0.141923     0.104124     0.026743
# 3     0.424915     0.470909     0.152728     0.130431     0.040273
# 4     0.037490     0.012440     0.037910     0.042405    -0.019231
# 5     0.354010     0.403931     0.136317     0.094650     0.029805
#
#    중랑구, 50대, 여  중랑구, 60대, 남  중랑구, 60대, 여               업종
# 0     0.032105    -0.140410    -0.100652  산업용 기계 및 장비 임대업
# 1     0.040405    -0.136346    -0.097204  산업용 기계 및 장비 임대업
# 3     0.031837    -0.113930    -0.067042  산업용 기계 및 장비 임대업
# 4     0.049486     0.023700     0.060874  산업용 기계 및 장비 임대업
# 5     0.027707    -0.142246    -0.096205  산업용 기계 및 장비 임대업
#
# [5 rows x 306 columns]

# %%
mean_corr_per_sector = df_corr.groupby(['업종']).mean()
display(mean_corr_per_sector.head())
# Out:
#                         총건수  강남구, 10대, 남  강남구, 10대, 여  강남구, 20대, 남  \
# 업종
# 1차 비철금속 제조업       -0.097576    -0.081651    -0.081729    -0.144930
# 1차 철강 제조업          0.020296     0.005030     0.005292    -0.003687
# 가구 제조업             0.012597    -0.049743    -0.087599     0.009434
# 가전제품 및 정보통신장비 소매업  0.243850     0.221267     0.213346     0.315300
# 가정용 기기 제조업        -0.288167    -0.243736    -0.228141    -0.453483
#
#                    강남구, 20대, 여  강남구, 30대, 남  강남구, 30대, 여  강남구, 40대, 남  \
# 업종
# 1차 비철금속 제조업          -0.171943    -0.122483    -0.137503    -0.027517
# 1차 철강 제조업            -0.012871     0.001594    -0.012251     0.007421
# 가구 제조업                0.006246    -0.003743     0.032007    -0.000713
# 가전제품 및 정보통신장비 소매업     0.363227     0.272635     0.293664     0.103641
# 가정용 기기 제조업           -0.495524    -0.342074    -0.385391    -0.037783
#
#                    강남구, 40대, 여  강남구, 50대, 남  ...  중랑구, 20대, 남  중랑구, 20대, 여  \
# 업종                                           ...
# 1차 비철금속 제조업           0.033339     0.043686  ...    -0.158462    -0.169514
# 1차 철강 제조업             0.021423     0.027428  ...     0.001887    -0.007519
# 가구 제조업                0.062322    -0.034983  ...    -0.002596    -0.002885
# 가전제품 및 정보통신장비 소매업    -0.035414    -0.071842  ...     0.376430     0.358079
# 가정용 기기 제조업            0.089753     0.112565  ...    -0.444171    -0.474776
#
#                    중랑구, 30대, 남  중랑구, 30대, 여  중랑구, 40대, 남  중랑구, 40대, 여  \
# 업종
# 1차 비철금속 제조업          -0.145435    -0.136072    -0.059520    -0.030679
# 1차 철강 제조업             0.004742     0.001926     0.016880     0.017380
# 가구 제조업               -0.001161     0.025780     0.000217     0.015651
# 가전제품 및 정보통신장비 소매업     0.374310     0.339500     0.197694     0.136746
# 가정용 기기 제조업           -0.401579    -0.393591    -0.125226    -0.052785
#
#                    중랑구, 50대, 남  중랑구, 50대, 여  중랑구, 60대, 남  중랑구, 60대, 여
# 업종
# 1차 비철금속 제조업           0.017110     0.040549     0.108375     0.101745
# 1차 철강 제조업             0.020295     0.035175     0.032004     0.033148
# 가구 제조업                0.007723     0.002990    -0.044243    -0.027172
# 가전제품 및 정보통신장비 소매업     0.017984     0.012892    -0.188809    -0.136121
# 가정용 기기 제조업            0.098145     0.169605     0.321585     0.257228
#
# [5 rows x 301 columns]

# %%
df_corr.columns
# Out:
# Index(['기업명', 'ticker', 'Correlation with', 'Time lag', '총건수', '강남구, 10대, 남',
#        '강남구, 10대, 여', '강남구, 20대, 남', '강남구, 20대, 여', '강남구, 30대, 남',
#        ...
#        '중랑구, 20대, 여', '중랑구, 30대, 남', '중랑구, 30대, 여', '중랑구, 40대, 남',
#        '중랑구, 40대, 여', '중랑구, 50대, 남', '중랑구, 50대, 여', '중랑구, 60대, 남',
#        '중랑구, 60대, 여', '업종'],
#       dtype='object', length=306)

# %% [markdown]
# # Get

# %% [markdown]
# # Get mean corrleation for given condition per sector

# %%
calls_original = pd.read_pickle('data/CALLS_CLIMATE.pkl')
display(calls_original.head())

sector_unique = df_corr['업종'].unique()
area_unique = calls_original['시군구'].unique()
sex_unique = calls_original['성별'].unique()
age_unique = calls_original['연령대'].unique()

df_corr_mean = pd.DataFrame(columns=['업종', '지역', '연령대', '성별', 'correlation'])
display(df_corr_mean)
display(df_corr.columns)

def get_correlation_for_given_combination(idx, sector, area, age, sex) : 
    #print('%s, %s, %s, %s' % (sector, area, age, sex))
    column_name = '%s, %s, %s' % (area, age, sex)
    target = df_corr[df_corr['Correlation with']=='Close']
    display(target)
    target = target[target['업종']==sector][column_name]
    display(target)
    mean_corr = target.mean()
    #print('mean corr for given combination : %s' % mean_corr)
    df_corr_mean.loc[idx] = [sector, area, age, sex, mean_corr]
    pbar.update(1)
    
    return
    
i = 0 
with tqdm.tqdm(total=(sector_unique.shape[0] * area_unique.shape[0] * age_unique.shape[0] * sex_unique.shape[0])) as pbar :
    for sector in sector_unique : 
        for area in area_unique : 
            for age in age_unique : 
                for sex in sex_unique : 
                    get_correlation_for_given_combination(i, sector, area, age, sex)
                    i += 1
# Out:
# -----------------------------------------------------------------------
# NameError                             Traceback (most recent call last)
# <ipython-input-1-0a2ee9dfb8e8> in <module>
# ----> 1 calls_original = pd.read_pickle('data/CALLS_CLIMATE.pkl')
#       2 display(calls_original.head())
#       3
#       4 sector_unique = df_corr['업종'].unique()
#       5 area_unique = calls_original['시군구'].unique()
#
# NameError: name 'pd' is not defined

# %%
df_corr_mean.to_pickle('metadata/df_corr_mean.pkl')
df_corr_mean.to_csv('metadata/df_corr_mean.csv')

# %%
df_corr_mean = pd.read_pickle('metadata/df_corr_mean.pkl')
df_corr_mean

# %% [markdown]
# # Plot Mean Correlations per Sector

# %%
colors = ['orange', 'skyblue', 'red', 'green', 'blue', 'brown']

# %%
for sector in df_corr_mean['업종'].unique() : 
    print(sector)
    target = df_corr_mean[df_corr_mean['업종']==sector]
    
    plt.figure(figsize=(20, 5))
    for idx, age in enumerate(df_corr_mean['연령대'].unique()) : 
        target_segmented = target[target['연령대']==age]
        
        plt.plot(target_segmented[target_segmented['성별']=='남']['correlation'].reset_index(drop=True), label='%s male, female' % age, c=colors[idx], alpha=0.3)
        plt.plot(target_segmented[target_segmented['성별']=='여']['correlation'].reset_index(drop=True), c=colors[idx], alpha=0.3)
    
    temp = target.groupby(['업종', '지역'])['correlation'].mean()
    mean = temp.iloc[temp.index.get_level_values('업종') == sector]

    plt.plot(mean.values, c='black', label='mean') 
    plt.xlabel('area')
    plt.ylabel('correlation')
    plt.legend()
    plt.show()

# %% [markdown]
# # Display Correlation

# %%
df_corr = df_corr[df_corr['Correlation with'] != 'High']
df_corr = df_corr[df_corr['Correlation with'] != 'Low']
df_corr = df_corr[df_corr['Correlation with'] != 'Volume']
df_corr = df_corr[df_corr['Correlation with'] != 'Open']

# %%
idx = 0
column_name = calls_amount[idx]

df_corr.groupby(['업종', 'Time lag', 'Correlation with'])[column_name].mean().sort_values()
# Out:
# 업종                        Time lag  Correlation with
# 소프트웨어 개발 및 공급업            0         Close              -0.536362
# 기반조성 및 시설물 축조관련 전문공사업     2         Close              -0.473060
#                           10        Close              -0.472510
#                           50        Close              -0.458782
# 석유 정제품 제조업                5         Close              -0.444110
#                                                           ...
# 합성고무 및 플라스틱 물질 제조업        2         Close               0.497212
# 석탄 광업                     2         Close               0.499183
#                           1         Close               0.500857
#                           0         Close               0.501070
# 건축기술, 엔지니어링 및 관련 기술 서비스업  1         Close               0.503192
# Name: 총건수, Length: 622, dtype: float64

# %%
time_lags = [0,1,2,5,10,25,50]

# %%
idx_time_lag = 0
mean_correlation = df_corr[df_corr['Time lag']==time_lags[idx_time_lag]].groupby(['업종', 'Time lag', 'Correlation with'])['총건수'].mean().sort_values()
display_all(mean_correlation)
# Out:
# 업종                                     Time lag  Correlation with
# 소프트웨어 개발 및 공급업                         0         Close              -0.536362
# 신발 및 신발 부분품 제조업                        0         Close              -0.438949
# 기타 비금속광물 광업                            0         Close              -0.414397
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업                0         Close              -0.410137
# 기타 전기장비 제조업                            0         Close              -0.397717
# 비료, 농약 및 살균, 살충제 제조업                   0         Close              -0.392454
# 육상 여객 운송업                              0         Close              -0.323178
# 가정용 기기 제조업                             0         Close              -0.316837
# 기계장비 및 관련 물품 도매업                       0         Close              -0.259661
# 금융 지원 서비스업                             0         Close              -0.257121
# 골판지, 종이 상자 및 종이용기 제조업                  0         Close              -0.245262
# 의료용 기기 제조업                             0         Close              -0.230914
# 부동산 임대 및 공급업                           0         Close              -0.219310
# 1차 비철금속 제조업                            0         Close              -0.219249
# 담배 제조업                                 0         Close              -0.217807
# 의약품 제조업                                0         Close              -0.194034
# 기타 종이 및 판지 제품 제조업                      0         Close              -0.152689
# 영상 및 음향기기 제조업                          0         Close              -0.143439
# 구조용 금속제품, 탱크 및 증기발생기 제조업               0         Close              -0.141846
# 직물직조 및 직물제품 제조업                        0         Close              -0.138692
# 전기 통신업                                 0         Close              -0.134695
# 자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업       0         Close              -0.134316
# 기초 화학물질 제조업                            0         Close              -0.133578
# 내화, 비내화 요업제품 제조업                       0         Close              -0.114463
# 통신 및 방송 장비 제조업                         0         Close              -0.109407
# 전자부품 제조업                               0         Close              -0.100891
# 기초 의약물질 및 생물학적 제제 제조업                  0         Close              -0.098591
# 그외 기타 개인 서비스업                          0         Close              -0.096824
# 기타 비금속 광물제품 제조업                        0         Close              -0.090502
# 반도체 제조업                                0         Close              -0.074476
# 생활용품 도매업                               0         Close              -0.062774
# 봉제의복 제조업                               0         Close              -0.061309
# 유리 및 유리제품 제조업                          0         Close              -0.047453
# 시멘트, 석회, 플라스터 및 그 제품 제조업               0         Close              -0.043913
# 곡물가공품, 전분 및 전분제품 제조업                   0         Close              -0.029926
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외  0         Close              -0.029472
# 토목 건설업                                 0         Close              -0.022371
# 상품 중개업                                 0         Close              -0.021672
# 철도장비 제조업                               0         Close              -0.016017
# 섬유, 의복, 신발 및 가죽제품 소매업                  0         Close              -0.009846
# 은행 및 저축기관                              0         Close              -0.003252
# 알코올음료 제조업                              0         Close              -0.002910
# 음·식료품 및 담배 도매업                         0         Close              -0.002086
# 여행사 및 기타 여행보조 서비스업                     0         Close              -0.000269
# 기타 금속 가공제품 제조업                         0         Close               0.002958
# 회사 본부 및 경영 컨설팅 서비스업                    0         Close               0.005621
# 광고업                                    0         Close               0.015617
# 특수 목적용 기계 제조업                          0         Close               0.022861
# 기타 상품 전문 소매업                           0         Close               0.027431
# 기타 금융업                                 0         Close               0.030928
# 1차 철강 제조업                              0         Close               0.034365
# 일반 목적용 기계 제조업                          0         Close               0.040659
# 기타 화학제품 제조업                            0         Close               0.051673
# 스포츠 서비스업                               0         Close               0.053384
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업      0         Close               0.056341
# 편조원단 제조업                               0         Close               0.062190
# 수산물 가공 및 저장 처리업                        0         Close               0.072645
# 항공 여객 운송업                              0         Close               0.083590
# 자동차용 엔진 및 자동차 제조업                      0         Close               0.094147
# 기타 전문 도매업                              0         Close               0.099519
# 선박 및 보트 건조업                            0         Close               0.108483
# 기타 식품 제조업                              0         Close               0.108735
# 가구 제조업                                 0         Close               0.115809
# 보험업                                    0         Close               0.122842
# 서적, 잡지 및 기타 인쇄물 출판업                    0         Close               0.123346
# 유원지 및 기타 오락관련 서비스업                     0         Close               0.123717
# 펄프, 종이 및 판지 제조업                        0         Close               0.126535
# 건축기술, 엔지니어링 및 관련 기술 서비스업               0         Close               0.127771
# 건물설비 설치 공사업                            0         Close               0.133655
# 초등 교육기관                                0         Close               0.143382
# 자동차 신품 부품 제조업                          0         Close               0.150245
# 플라스틱제품 제조업                             0         Close               0.151795
# 종합 소매업                                 0         Close               0.154188
# 해상 운송업                                 0         Close               0.161357
# 도로 화물 운송업                              0         Close               0.164356
# 연료용 가스 제조 및 배관공급업                      0         Close               0.164602
# 운송장비 임대업                               0         Close               0.173546
# 화학섬유 제조업                               0         Close               0.183359
# 건물 건설업                                 0         Close               0.184185
# 나무제품 제조업                               0         Close               0.185251
# 낙농제품 및 식용빙과류 제조업                       0         Close               0.205455
# 가죽, 가방 및 유사제품 제조업                      0         Close               0.209201
# 전기업                                    0         Close               0.264859
# 일반 및 생활 숙박시설 운영업                       0         Close               0.276344
# 기타 정보 서비스업                             0         Close               0.285015
# 그외 기타 운송장비 제조업                         0         Close               0.313219
# 기타 운송관련 서비스업                           0         Close               0.320373
# 산업용 기계 및 장비 임대업                        0         Close               0.351568
# 방적 및 가공사 제조업                           0         Close               0.367039
# 절연선 및 케이블 제조업                          0         Close               0.378895
# 영화, 비디오물, 방송프로그램 제작 및 배급업              0         Close               0.380712
# 고무제품 제조업                               0         Close               0.399976
# 신탁업 및 집합투자업                            0         Close               0.417810
# 텔레비전 방송업                               0         Close               0.419707
# 석유 정제품 제조업                             0         Close               0.453544
# 전구 및 조명장치 제조업                          0         Close               0.461717
# 전기 및 통신 공사업                            0         Close               0.464719
# 무점포 소매업                                0         Close               0.465774
# 상품 종합 도매업                              0         Close               0.478149
# 석탄 광업                                  0         Close               0.501070
# Name: 총건수, dtype: float64

# %%
idx_time_lag = 1
mean_correlation = df_corr[df_corr['Time lag']==time_lags[idx_time_lag]].groupby(['업종', 'Time lag', 'Correlation with'])['총건수'].mean().sort_values()
display_all(mean_correlation)
# Out:
# 업종                                     Time lag  Correlation with
# 기반조성 및 시설물 축조관련 전문공사업                  1         Close              -0.443611
# 영상 및 음향기기 제조업                          1         Close              -0.430170
# 기타 전기장비 제조업                            1         Close              -0.399677
# 비료, 농약 및 살균, 살충제 제조업                   1         Close              -0.394840
# 직물직조 및 직물제품 제조업                        1         Close              -0.374695
# 섬유, 의복, 신발 및 가죽제품 소매업                  1         Close              -0.346344
# 가정용 기기 제조업                             1         Close              -0.316324
# 구조용 금속제품, 탱크 및 증기발생기 제조업               1         Close              -0.294973
# 골판지, 종이 상자 및 종이용기 제조업                  1         Close              -0.280872
# 기계장비 및 관련 물품 도매업                       1         Close              -0.256284
# 육상 여객 운송업                              1         Close              -0.237220
# 의료용 기기 제조업                             1         Close              -0.235842
# 생활용품 도매업                               1         Close              -0.233825
# 의약품 제조업                                1         Close              -0.222480
# 석유 정제품 제조업                             1         Close              -0.214841
# 통신 및 방송 장비 제조업                         1         Close              -0.197367
# 선박 및 보트 건조업                            1         Close              -0.186617
# 내화, 비내화 요업제품 제조업                       1         Close              -0.185632
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업                1         Close              -0.179251
# 개인 및 가정용품 임대업                          1         Close              -0.178492
# 영화, 비디오물, 방송프로그램 제작 및 배급업              1         Close              -0.176244
# 서적, 잡지 및 기타 인쇄물 출판업                    1         Close              -0.165546
# 자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업       1         Close              -0.160605
# 기초 화학물질 제조업                            1         Close              -0.151796
# 반도체 제조업                                1         Close              -0.150502
# 전기 통신업                                 1         Close              -0.136650
# 금융 지원 서비스업                             1         Close              -0.110680
# 소프트웨어 개발 및 공급업                         1         Close              -0.105919
# 기타 금속 가공제품 제조업                         1         Close              -0.099200
# 기초 의약물질 및 생물학적 제제 제조업                  1         Close              -0.098116
# 수산물 가공 및 저장 처리업                        1         Close              -0.095085
# 전자부품 제조업                               1         Close              -0.069673
# 건물 건설업                                 1         Close              -0.042196
# 유리 및 유리제품 제조업                          1         Close              -0.028889
# 은행 및 저축기관                              1         Close              -0.005541
# 회사 본부 및 경영 컨설팅 서비스업                    1         Close              -0.005303
# 여행사 및 기타 여행보조 서비스업                     1         Close              -0.000200
# 음식점업                                   1         Close               0.005364
# 도로 화물 운송업                              1         Close               0.007807
# 1차 철강 제조업                              1         Close               0.009480
# 보험업                                    1         Close               0.021724
# 항공 여객 운송업                              1         Close               0.042603
# 스포츠 서비스업                               1         Close               0.044658
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업      1         Close               0.057702
# 기타 화학제품 제조업                            1         Close               0.058857
# 기타 금융업                                 1         Close               0.063727
# 해상 운송업                                 1         Close               0.088011
# 절연선 및 케이블 제조업                          1         Close               0.090222
# 부동산 임대 및 공급업                           1         Close               0.094337
# 기타 운송관련 서비스업                           1         Close               0.102634
# 기타 식품 제조업                              1         Close               0.111203
# 1차 비철금속 제조업                            1         Close               0.115158
# 일반 목적용 기계 제조업                          1         Close               0.116794
# 신탁업 및 집합투자업                            1         Close               0.125472
# 무기 및 총포탄 제조업                           1         Close               0.134793
# 금속 주조업                                 1         Close               0.144085
# 인형,장난감 및 오락용품 제조업                      1         Close               0.148477
# 곡물가공품, 전분 및 전분제품 제조업                   1         Close               0.150084
# 비알코올음료 및 얼음 제조업                        1         Close               0.151963
# 특수 목적용 기계 제조업                          1         Close               0.156075
# 자동차 신품 부품 제조업                          1         Close               0.162159
# 동물용 사료 및 조제식품 제조업                      1         Close               0.165916
# 시멘트, 석회, 플라스터 및 그 제품 제조업               1         Close               0.166577
# 봉제의복 제조업                               1         Close               0.169543
# 기타 사업지원 서비스업                           1         Close               0.177337
# 화학섬유 제조업                               1         Close               0.185387
# 상품 종합 도매업                              1         Close               0.185792
# 플라스틱제품 제조업                             1         Close               0.186954
# 가구 제조업                                 1         Close               0.195714
# 항공기,우주선 및 부품 제조업                       1         Close               0.204229
# 기타 전문 도매업                              1         Close               0.204397
# 토목 건설업                                 1         Close               0.205669
# 일차전지 및 축전지 제조업                         1         Close               0.211269
# 연료용 가스 제조 및 배관공급업                      1         Close               0.218598
# 가죽, 가방 및 유사제품 제조업                      1         Close               0.223948
# 기타 비금속 광물제품 제조업                        1         Close               0.230266
# 전기업                                    1         Close               0.263626
# 기타 정보 서비스업                             1         Close               0.273184
# 일반 및 생활 숙박시설 운영업                       1         Close               0.277081
# 종합 소매업                                 1         Close               0.283149
# 낙농제품 및 식용빙과류 제조업                       1         Close               0.344639
# 연료 소매업                                 1         Close               0.366522
# 운송장비 임대업                               1         Close               0.368300
# 텔레비전 방송업                               1         Close               0.370268
# 펄프, 종이 및 판지 제조업                        1         Close               0.394714
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외  1         Close               0.395761
# 고무제품 제조업                               1         Close               0.397501
# 자동차용 엔진 및 자동차 제조업                      1         Close               0.403887
# 어로 어업                                  1         Close               0.445996
# 전기 및 통신 공사업                            1         Close               0.458763
# 전구 및 조명장치 제조업                          1         Close               0.459392
# 컴퓨터 및 주변장치 제조업                         1         Close               0.476690
# 합성고무 및 플라스틱 물질 제조업                     1         Close               0.493223
# 석탄 광업                                  1         Close               0.500857
# 건축기술, 엔지니어링 및 관련 기술 서비스업               1         Close               0.503192
# Name: 총건수, dtype: float64

# %%
idx_time_lag = 2
mean_correlation = df_corr[df_corr['Time lag']==time_lags[idx_time_lag]].groupby(['업종', 'Time lag', 'Correlation with'])['총건수'].mean().sort_values()
display_all(mean_correlation)
# Out:
# 업종                                 Time lag  Correlation with
# 기반조성 및 시설물 축조관련 전문공사업              2         Close              -0.473060
# 기타 비금속 광물제품 제조업                    2         Close              -0.435046
# 비료, 농약 및 살균, 살충제 제조업               2         Close              -0.393998
# 전자부품 제조업                           2         Close              -0.383837
# 골판지, 종이 상자 및 종이용기 제조업              2         Close              -0.383591
# 직물직조 및 직물제품 제조업                    2         Close              -0.374173
# 화학섬유 제조업                           2         Close              -0.371832
# 기타 운송관련 서비스업                       2         Close              -0.321981
# 도축, 육류 가공 및 저장 처리업                 2         Close              -0.318824
# 가정용 기기 제조업                         2         Close              -0.317399
# 반도체 제조업                            2         Close              -0.316703
# 기타 금속 가공제품 제조업                     2         Close              -0.279451
# 내화, 비내화 요업제품 제조업                   2         Close              -0.276211
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업            2         Close              -0.254260
# 기초 화학물질 제조업                        2         Close              -0.250199
# 생활용품 도매업                           2         Close              -0.249980
# 의료용 기기 제조업                         2         Close              -0.232616
# 1차 비철금속 제조업                        2         Close              -0.175813
# 통신 및 방송 장비 제조업                     2         Close              -0.174038
# 의약품 제조업                            2         Close              -0.157135
# 자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업   2         Close              -0.130272
# 금융 지원 서비스업                         2         Close              -0.115272
# 광고업                                2         Close              -0.104942
# 편조원단 제조업                           2         Close              -0.082720
# 보험업                                2         Close              -0.072527
# 부동산 임대 및 공급업                       2         Close              -0.065860
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업  2         Close              -0.056565
# 일차전지 및 축전지 제조업                     2         Close              -0.042467
# 전기 통신업                             2         Close              -0.041128
# 토목 건설업                             2         Close              -0.035451
# 항공 여객 운송업                          2         Close              -0.034640
# 건물 건설업                             2         Close              -0.033395
# 건축기술, 엔지니어링 및 관련 기술 서비스업           2         Close              -0.027268
# 1차 철강 제조업                          2         Close              -0.021531
# 기계장비 및 관련 물품 도매업                   2         Close              -0.020410
# 회사 본부 및 경영 컨설팅 서비스업                2         Close              -0.011087
# 항공기,우주선 및 부품 제조업                   2         Close               0.016050
# 석유 정제품 제조업                         2         Close               0.023571
# 기타 화학제품 제조업                        2         Close               0.025294
# 기타 금융업                             2         Close               0.044553
# 영화, 비디오물, 방송프로그램 제작 및 배급업          2         Close               0.046087
# 기타 식품 제조업                          2         Close               0.050392
# 초등 교육기관                            2         Close               0.053467
# 상품 중개업                             2         Close               0.062349
# 소프트웨어 개발 및 공급업                     2         Close               0.074680
# 기초 의약물질 및 생물학적 제제 제조업              2         Close               0.080220
# 특수 목적용 기계 제조업                      2         Close               0.088507
# 일반 목적용 기계 제조업                      2         Close               0.088609
# 가구 제조업                             2         Close               0.106500
# 봉제의복 제조업                           2         Close               0.114403
# 서적, 잡지 및 기타 인쇄물 출판업                2         Close               0.117050
# 음·식료품 및 담배 도매업                     2         Close               0.131596
# 기타 전문 도매업                          2         Close               0.145280
# 건물설비 설치 공사업                        2         Close               0.148666
# 해상 운송업                             2         Close               0.171023
# 나무제품 제조업                           2         Close               0.179636
# 운송장비 임대업                           2         Close               0.179681
# 상품 종합 도매업                          2         Close               0.186294
# 가죽, 가방 및 유사제품 제조업                  2         Close               0.208270
# 펄프, 종이 및 판지 제조업                    2         Close               0.222048
# 곡물가공품, 전분 및 전분제품 제조업               2         Close               0.224208
# 종합 소매업                             2         Close               0.224786
# 연료용 가스 제조 및 배관공급업                  2         Close               0.232394
# 알코올음료 제조업                          2         Close               0.235796
# 자동차 신품 부품 제조업                      2         Close               0.252902
# 고무제품 제조업                           2         Close               0.273131
# 신탁업 및 집합투자업                        2         Close               0.276191
# 일반 및 생활 숙박시설 운영업                   2         Close               0.279216
# 기타 정보 서비스업                         2         Close               0.279312
# 시멘트, 석회, 플라스터 및 그 제품 제조업           2         Close               0.291990
# 플라스틱제품 제조업                         2         Close               0.293572
# 제재 및 목재 가공업                        2         Close               0.298127
# 절연선 및 케이블 제조업                      2         Close               0.311601
# 낙농제품 및 식용빙과류 제조업                   2         Close               0.338344
# 산업용 기계 및 장비 임대업                    2         Close               0.342827
# 연료 소매업                             2         Close               0.364250
# 텔레비전 방송업                           2         Close               0.382435
# 자동차용 엔진 및 자동차 제조업                  2         Close               0.384943
# 자동차 부품 및 내장품 판매업                   2         Close               0.405294
# 무점포 소매업                            2         Close               0.410574
# 유원지 및 기타 오락관련 서비스업                 2         Close               0.414249
# 전기 및 통신 공사업                        2         Close               0.455808
# 전구 및 조명장치 제조업                      2         Close               0.458327
# 도로 화물 운송업                          2         Close               0.471694
# 무기 및 총포탄 제조업                       2         Close               0.484505
# 합성고무 및 플라스틱 물질 제조업                 2         Close               0.497212
# 석탄 광업                              2         Close               0.499183
# Name: 총건수, dtype: float64

# %%
idx_time_lag = 3
mean_correlation = df_corr[df_corr['Time lag']==time_lags[idx_time_lag]].groupby(['업종', 'Time lag', 'Correlation with'])['총건수'].mean().sort_values()
display_all(mean_correlation)
# Out:
# 업종                                     Time lag  Correlation with
# 석유 정제품 제조업                             5         Close              -0.444110
# 건축기술, 엔지니어링 및 관련 기술 서비스업               5         Close              -0.436889
# 기타 비금속광물 광업                            5         Close              -0.413577
# 자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업       5         Close              -0.396188
# 화학섬유 제조업                               5         Close              -0.371046
# 구조용 금속제품, 탱크 및 증기발생기 제조업               5         Close              -0.344101
# 비료, 농약 및 살균, 살충제 제조업                   5         Close              -0.327262
# 가정용 기기 제조업                             5         Close              -0.321102
# 의약품 제조업                                5         Close              -0.254586
# 내화, 비내화 요업제품 제조업                       5         Close              -0.251931
# 전자부품 제조업                               5         Close              -0.226244
# 가구 제조업                                 5         Close              -0.198435
# 개인 및 가정용품 임대업                          5         Close              -0.187016
# 선박 및 보트 건조업                            5         Close              -0.186959
# 반도체 제조업                                5         Close              -0.142359
# 어로 어업                                  5         Close              -0.111445
# 기타 운송관련 서비스업                           5         Close              -0.111388
# 기타 금속 가공제품 제조업                         5         Close              -0.099276
# 통신 및 방송 장비 제조업                         5         Close              -0.093155
# 기초 화학물질 제조업                            5         Close              -0.090167
# 생활용품 도매업                               5         Close              -0.068178
# 유리 및 유리제품 제조업                          5         Close              -0.050741
# 항공 여객 운송업                              5         Close              -0.049228
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업                5         Close              -0.042121
# 1차 비철금속 제조업                            5         Close              -0.013671
# 회사 본부 및 경영 컨설팅 서비스업                    5         Close              -0.003521
# 1차 철강 제조업                              5         Close               0.012281
# 금융 지원 서비스업                             5         Close               0.013023
# 기타 상품 전문 소매업                           5         Close               0.023514
# 기타 화학제품 제조업                            5         Close               0.025443
# 전기 통신업                                 5         Close               0.025520
# 스포츠 서비스업                               5         Close               0.028711
# 소프트웨어 개발 및 공급업                         5         Close               0.043292
# 기타 전문 도매업                              5         Close               0.043319
# 기타 식품 제조업                              5         Close               0.043928
# 상품 중개업                                 5         Close               0.062146
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업      5         Close               0.066664
# 기초 의약물질 및 생물학적 제제 제조업                  5         Close               0.084020
# 보험업                                    5         Close               0.095833
# 봉제의복 제조업                               5         Close               0.097525
# 토목 건설업                                 5         Close               0.100770
# 상품 종합 도매업                              5         Close               0.101643
# 은행 및 저축기관                              5         Close               0.102335
# 일반 목적용 기계 제조업                          5         Close               0.108854
# 건물설비 설치 공사업                            5         Close               0.122871
# 음·식료품 및 담배 도매업                         5         Close               0.125937
# 무기 및 총포탄 제조업                           5         Close               0.131450
# 금속 주조업                                 5         Close               0.134215
# 연료용 가스 제조 및 배관공급업                      5         Close               0.139929
# 특수 목적용 기계 제조업                          5         Close               0.140584
# 곡물가공품, 전분 및 전분제품 제조업                   5         Close               0.145764
# 인형,장난감 및 오락용품 제조업                      5         Close               0.152716
# 기타 금융업                                 5         Close               0.153318
# 건물 건설업                                 5         Close               0.157774
# 가죽, 가방 및 유사제품 제조업                      5         Close               0.158540
# 영화, 비디오물, 방송프로그램 제작 및 배급업              5         Close               0.172660
# 부동산 임대 및 공급업                           5         Close               0.214135
# 자동차 신품 부품 제조업                          5         Close               0.225447
# 재 보험업                                  5         Close               0.230195
# 초등 교육기관                                5         Close               0.234976
# 알코올음료 제조업                              5         Close               0.236607
# 종합 소매업                                 5         Close               0.247894
# 일반 및 생활 숙박시설 운영업                       5         Close               0.272147
# 플라스틱제품 제조업                             5         Close               0.318472
# 해상 운송업                                 5         Close               0.325209
# 영상 및 음향기기 제조업                          5         Close               0.326584
# 텔레비전 방송업                               5         Close               0.343727
# 산업용 기계 및 장비 임대업                        5         Close               0.345279
# 연료 소매업                                 5         Close               0.355338
# 자동차용 엔진 및 자동차 제조업                      5         Close               0.355632
# 운송장비 임대업                               5         Close               0.384892
# 펄프, 종이 및 판지 제조업                        5         Close               0.393020
# 신탁업 및 집합투자업                            5         Close               0.398606
# 전기 및 통신 공사업                            5         Close               0.450354
# 고무제품 제조업                               5         Close               0.453293
# 전구 및 조명장치 제조업                          5         Close               0.457376
# 시멘트, 석회, 플라스터 및 그 제품 제조업               5         Close               0.470487
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외  5         Close               0.483859
# Name: 총건수, dtype: float64

# %%
idx_time_lag = 4
mean_correlation = df_corr[df_corr['Time lag']==time_lags[idx_time_lag]].groupby(['업종', 'Time lag', 'Correlation with'])['총건수'].mean().sort_values()
display_all(mean_correlation)
# Out:
# 업종                                     Time lag  Correlation with
# 기반조성 및 시설물 축조관련 전문공사업                  10        Close              -0.472510
# 건축자재, 철물 및 난방장치 도매업                    10        Close              -0.426311
# 영상 및 음향기기 제조업                          10        Close              -0.423370
# 비료, 농약 및 살균, 살충제 제조업                   10        Close              -0.420431
# 기타 비금속광물 광업                            10        Close              -0.409488
# 여행사 및 기타 여행보조 서비스업                     10        Close              -0.349297
# 반도체 제조업                                10        Close              -0.338703
# 가정용 기기 제조업                             10        Close              -0.326148
# 절연선 및 케이블 제조업                          10        Close              -0.268056
# 육상 여객 운송업                              10        Close              -0.261055
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업                10        Close              -0.257308
# 무기 및 총포탄 제조업                           10        Close              -0.222316
# 골판지, 종이 상자 및 종이용기 제조업                  10        Close              -0.221534
# 항공 여객 운송업                              10        Close              -0.207094
# 의료용 기기 제조업                             10        Close              -0.201896
# 의약품 제조업                                10        Close              -0.200685
# 선박 및 보트 건조업                            10        Close              -0.185571
# 영화, 비디오물, 방송프로그램 제작 및 배급업              10        Close              -0.176896
# 서적, 잡지 및 기타 인쇄물 출판업                    10        Close              -0.165746
# 전기 통신업                                 10        Close              -0.162684
# 자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업       10        Close              -0.159087
# 1차 비철금속 제조업                            10        Close              -0.154220
# 기타 화학제품 제조업                            10        Close              -0.150291
# 건물 건설업                                 10        Close              -0.145048
# 금융 지원 서비스업                             10        Close              -0.134341
# 기초 화학물질 제조업                            10        Close              -0.120624
# 기타 비금속 광물제품 제조업                        10        Close              -0.120437
# 그외 기타 개인 서비스업                          10        Close              -0.103493
# 통신 및 방송 장비 제조업                         10        Close              -0.095442
# 부동산 임대 및 공급업                           10        Close              -0.060246
# 생활용품 도매업                               10        Close              -0.059949
# 유리 및 유리제품 제조업                          10        Close              -0.053199
# 기계장비 및 관련 물품 도매업                       10        Close              -0.043089
# 은행 및 저축기관                              10        Close              -0.019721
# 시멘트, 석회, 플라스터 및 그 제품 제조업               10        Close              -0.017270
# 석유 정제품 제조업                             10        Close               0.000833
# 해상 운송업                                 10        Close               0.001101
# 기타 금속 가공제품 제조업                         10        Close               0.004654
# 회사 본부 및 경영 컨설팅 서비스업                    10        Close               0.005255
# 1차 철강 제조업                              10        Close               0.012191
# 내화, 비내화 요업제품 제조업                       10        Close               0.020008
# 기타 금융업                                 10        Close               0.023494
# 전자부품 제조업                               10        Close               0.028257
# 소프트웨어 개발 및 공급업                         10        Close               0.033322
# 종합 소매업                                 10        Close               0.058491
# 곡물가공품, 전분 및 전분제품 제조업                   10        Close               0.077854
# 토목 건설업                                 10        Close               0.093938
# 광고업                                    10        Close               0.095233
# 기초 의약물질 및 생물학적 제제 제조업                  10        Close               0.096336
# 특수 목적용 기계 제조업                          10        Close               0.114621
# 가구 제조업                                 10        Close               0.117634
# 건물설비 설치 공사업                            10        Close               0.120667
# 어로 어업                                  10        Close               0.125404
# 금속 주조업                                 10        Close               0.126769
# 나무제품 제조업                               10        Close               0.130313
# 기타 식품 제조업                              10        Close               0.134197
# 초등 교육기관                                10        Close               0.148494
# 기타 전문 도매업                              10        Close               0.148880
# 인형,장난감 및 오락용품 제조업                      10        Close               0.156069
# 일반 목적용 기계 제조업                          10        Close               0.157073
# 봉제의복 제조업                               10        Close               0.160327
# 보험업                                    10        Close               0.167254
# 기타 운송관련 서비스업                           10        Close               0.182412
# 기타 사업지원 서비스업                           10        Close               0.184943
# 알코올음료 제조업                              10        Close               0.239461
# 플라스틱제품 제조업                             10        Close               0.245171
# 펄프, 종이 및 판지 제조업                        10        Close               0.248515
# 기타 정보 서비스업                             10        Close               0.262148
# 일반 및 생활 숙박시설 운영업                       10        Close               0.266285
# 구조용 금속제품, 탱크 및 증기발생기 제조업               10        Close               0.283193
# 방적 및 가공사 제조업                           10        Close               0.288016
# 자동차 신품 부품 제조업                          10        Close               0.302865
# 제재 및 목재 가공업                            10        Close               0.307098
# 낙농제품 및 식용빙과류 제조업                       10        Close               0.310004
# 연료용 가스 제조 및 배관공급업                      10        Close               0.324573
# 텔레비전 방송업                               10        Close               0.328362
# 신탁업 및 집합투자업                            10        Close               0.331116
# 건축기술, 엔지니어링 및 관련 기술 서비스업               10        Close               0.336782
# 산업용 기계 및 장비 임대업                        10        Close               0.338447
# 상품 종합 도매업                              10        Close               0.339284
# 연료 소매업                                 10        Close               0.340651
# 운송장비 임대업                               10        Close               0.354857
# 자동차용 엔진 및 자동차 제조업                      10        Close               0.367678
# 자동차 부품 및 내장품 판매업                       10        Close               0.392825
# 유원지 및 기타 오락관련 서비스업                     10        Close               0.401891
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업      10        Close               0.426993
# 전구 및 조명장치 제조업                          10        Close               0.453594
# 고무제품 제조업                               10        Close               0.457165
# 상품 중개업                                 10        Close               0.461437
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외  10        Close               0.477170
# 합성고무 및 플라스틱 물질 제조업                     10        Close               0.481156
# 석탄 광업                                  10        Close               0.487599
# Name: 총건수, dtype: float64

# %%
idx_time_lag = 5
mean_correlation = df_corr[df_corr['Time lag']==time_lags[idx_time_lag]].groupby(['업종', 'Time lag', 'Correlation with'])['총건수'].mean().sort_values()
display_all(mean_correlation)
# Out:
# 업종                                 Time lag  Correlation with
# 건축자재, 철물 및 난방장치 도매업                25        Close              -0.426042
# 비료, 농약 및 살균, 살충제 제조업               25        Close              -0.417338
# 기타 전기장비 제조업                        25        Close              -0.400052
# 기타 비금속광물 광업                        25        Close              -0.393580
# 화학섬유 제조업                           25        Close              -0.381732
# 도축, 육류 가공 및 저장 처리업                 25        Close              -0.363673
# 여행사 및 기타 여행보조 서비스업                 25        Close              -0.340040
# 가정용 기기 제조업                         25        Close              -0.327834
# 내화, 비내화 요업제품 제조업                   25        Close              -0.319636
# 반도체 제조업                            25        Close              -0.312704
# 골판지, 종이 상자 및 종이용기 제조업              25        Close              -0.296500
# 기계장비 및 관련 물품 도매업                   25        Close              -0.230251
# 1차 비철금속 제조업                        25        Close              -0.224106
# 의약품 제조업                            25        Close              -0.219377
# 무기 및 총포탄 제조업                       25        Close              -0.215227
# 기타 금속 가공제품 제조업                     25        Close              -0.192722
# 전기 통신업                             25        Close              -0.160182
# 기타 화학제품 제조업                        25        Close              -0.157816
# 기초 화학물질 제조업                        25        Close              -0.155839
# 개인 및 가정용품 임대업                      25        Close              -0.135950
# 그외 기타 개인 서비스업                      25        Close              -0.100954
# 금융 지원 서비스업                         25        Close              -0.098576
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업            25        Close              -0.079500
# 석유 정제품 제조업                         25        Close              -0.070257
# 일차전지 및 축전지 제조업                     25        Close              -0.068044
# 유리 및 유리제품 제조업                      25        Close              -0.061210
# 통신 및 방송 장비 제조업                     25        Close              -0.054374
# 가구 제조업                             25        Close              -0.050796
# 보험업                                25        Close              -0.049433
# 건축기술, 엔지니어링 및 관련 기술 서비스업           25        Close              -0.047486
# 스포츠 서비스업                           25        Close              -0.026103
# 은행 및 저축기관                          25        Close              -0.025069
# 토목 건설업                             25        Close              -0.022120
# 선박 및 보트 건조업                        25        Close              -0.017103
# 음식점업                               25        Close               0.002177
# 일반 목적용 기계 제조업                      25        Close               0.003735
# 종합 소매업                             25        Close               0.008877
# 곡물가공품, 전분 및 전분제품 제조업               25        Close               0.026357
# 기타 운송관련 서비스업                       25        Close               0.028346
# 기타 식품 제조업                          25        Close               0.030473
# 건물 건설업                             25        Close               0.031455
# 소프트웨어 개발 및 공급업                     25        Close               0.036208
# 영화, 비디오물, 방송프로그램 제작 및 배급업          25        Close               0.038468
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업  25        Close               0.043281
# 1차 철강 제조업                          25        Close               0.055814
# 봉제의복 제조업                           25        Close               0.059189
# 기타 금융업                             25        Close               0.079786
# 항공 여객 운송업                          25        Close               0.087288
# 전자부품 제조업                           25        Close               0.087435
# 서적, 잡지 및 기타 인쇄물 출판업                25        Close               0.097965
# 자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업   25        Close               0.099956
# 부동산 임대 및 공급업                       25        Close               0.128652
# 기초 의약물질 및 생물학적 제제 제조업              25        Close               0.134851
# 상품 중개업                             25        Close               0.136164
# 생활용품 도매업                           25        Close               0.181704
# 건물설비 설치 공사업                        25        Close               0.182001
# 운송장비 임대업                           25        Close               0.187876
# 인형,장난감 및 오락용품 제조업                  25        Close               0.203672
# 해상 운송업                             25        Close               0.210387
# 특수 목적용 기계 제조업                      25        Close               0.218828
# 알코올음료 제조업                          25        Close               0.218943
# 기타 전문 도매업                          25        Close               0.222984
# 상품 종합 도매업                          25        Close               0.223790
# 재 보험업                              25        Close               0.225216
# 자동차 신품 부품 제조업                      25        Close               0.262332
# 신탁업 및 집합투자업                        25        Close               0.292546
# 텔레비전 방송업                           25        Close               0.293213
# 낙농제품 및 식용빙과류 제조업                   25        Close               0.300992
# 산업용 기계 및 장비 임대업                    25        Close               0.331671
# 플라스틱제품 제조업                         25        Close               0.343046
# 펄프, 종이 및 판지 제조업                    25        Close               0.355779
# 자동차 부품 및 내장품 판매업                   25        Close               0.356719
# 회사 본부 및 경영 컨설팅 서비스업                25        Close               0.380324
# 어로 어업                              25        Close               0.382144
# 자동차용 엔진 및 자동차 제조업                  25        Close               0.406724
# 가죽, 가방 및 유사제품 제조업                  25        Close               0.413937
# 연료용 가스 제조 및 배관공급업                  25        Close               0.441811
# 시멘트, 석회, 플라스터 및 그 제품 제조업           25        Close               0.443804
# 고무제품 제조업                           25        Close               0.451749
# 절연선 및 케이블 제조업                      25        Close               0.457608
# 석탄 광업                              25        Close               0.466695
# 합성고무 및 플라스틱 물질 제조업                 25        Close               0.485209
# Name: 총건수, dtype: float64

# %%
idx_time_lag = 6
mean_correlation = df_corr[df_corr['Time lag']==time_lags[idx_time_lag]].groupby(['업종', 'Time lag', 'Correlation with'])['총건수'].mean().sort_values()
display_all(mean_correlation)
# Out:
# 업종                                     Time lag  Correlation with
# 기반조성 및 시설물 축조관련 전문공사업                  50        Close              -0.458782
# 건축자재, 철물 및 난방장치 도매업                    50        Close              -0.422748
# 기타 전기장비 제조업                            50        Close              -0.415287
# 비료, 농약 및 살균, 살충제 제조업                   50        Close              -0.376637
# 도축, 육류 가공 및 저장 처리업                     50        Close              -0.373434
# 선박 및 보트 건조업                            50        Close              -0.364573
# 골판지, 종이 상자 및 종이용기 제조업                  50        Close              -0.352815
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외  50        Close              -0.352105
# 석유 정제품 제조업                             50        Close              -0.330144
# 가정용 기기 제조업                             50        Close              -0.327002
# 건축기술, 엔지니어링 및 관련 기술 서비스업               50        Close              -0.221280
# 1차 비철금속 제조업                            50        Close              -0.204275
# 전자부품 제조업                               50        Close              -0.202453
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업                50        Close              -0.188818
# 토목 건설업                                 50        Close              -0.183384
# 의약품 제조업                                50        Close              -0.163090
# 서적, 잡지 및 기타 인쇄물 출판업                    50        Close              -0.157442
# 통신 및 방송 장비 제조업                         50        Close              -0.154871
# 전기 통신업                                 50        Close              -0.143876
# 곡물가공품, 전분 및 전분제품 제조업                   50        Close              -0.141314
# 반도체 제조업                                50        Close              -0.140210
# 시멘트, 석회, 플라스터 및 그 제품 제조업               50        Close              -0.138533
# 보험업                                    50        Close              -0.132156
# 도로 화물 운송업                              50        Close              -0.117827
# 어로 어업                                  50        Close              -0.111629
# 의료용 기기 제조업                             50        Close              -0.103790
# 기초 화학물질 제조업                            50        Close              -0.083692
# 유리 및 유리제품 제조업                          50        Close              -0.082191
# 개인 및 가정용품 임대업                          50        Close              -0.070241
# 소프트웨어 개발 및 공급업                         50        Close              -0.068452
# 편조원단 제조업                               50        Close              -0.053978
# 은행 및 저축기관                              50        Close              -0.047133
# 생활용품 도매업                               50        Close              -0.039326
# 가구 제조업                                 50        Close              -0.035999
# 기계장비 및 관련 물품 도매업                       50        Close              -0.035148
# 기타 화학제품 제조업                            50        Close              -0.019884
# 금융 지원 서비스업                             50        Close              -0.009624
# 기초 의약물질 및 생물학적 제제 제조업                  50        Close              -0.003444
# 구조용 금속제품, 탱크 및 증기발생기 제조업               50        Close               0.014004
# 일반 목적용 기계 제조업                          50        Close               0.015134
# 금속 주조업                                 50        Close               0.029546
# 기타 금융업                                 50        Close               0.031458
# 회사 본부 및 경영 컨설팅 서비스업                    50        Close               0.039850
# 1차 철강 제조업                              50        Close               0.042451
# 봉제의복 제조업                               50        Close               0.046416
# 펄프, 종이 및 판지 제조업                        50        Close               0.048633
# 초등 교육기관                                50        Close               0.056832
# 기타 전문 도매업                              50        Close               0.057727
# 유원지 및 기타 오락관련 서비스업                     50        Close               0.064296
# 부동산 임대 및 공급업                           50        Close               0.087749
# 상품 종합 도매업                              50        Close               0.096705
# 절연선 및 케이블 제조업                          50        Close               0.098883
# 나무제품 제조업                               50        Close               0.105422
# 항공 여객 운송업                              50        Close               0.116512
# 자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업       50        Close               0.129721
# 종합 소매업                                 50        Close               0.160584
# 내화, 비내화 요업제품 제조업                       50        Close               0.164497
# 건물 건설업                                 50        Close               0.168950
# 제재 및 목재 가공업                            50        Close               0.171149
# 낙농제품 및 식용빙과류 제조업                       50        Close               0.175999
# 자동차 신품 부품 제조업                          50        Close               0.178585
# 플라스틱제품 제조업                             50        Close               0.183852
# 재 보험업                                  50        Close               0.188817
# 해상 운송업                                 50        Close               0.193368
# 기타 식품 제조업                              50        Close               0.206344
# 영화, 비디오물, 방송프로그램 제작 및 배급업              50        Close               0.220055
# 특수 목적용 기계 제조업                          50        Close               0.226125
# 일반 및 생활 숙박시설 운영업                       50        Close               0.243951
# 방적 및 가공사 제조업                           50        Close               0.253965
# 건물설비 설치 공사업                            50        Close               0.255022
# 연료용 가스 제조 및 배관공급업                      50        Close               0.264623
# 가죽, 가방 및 유사제품 제조업                      50        Close               0.268219
# 연료 소매업                                 50        Close               0.276226
# 인형,장난감 및 오락용품 제조업                      50        Close               0.283768
# 산업용 기계 및 장비 임대업                        50        Close               0.290682
# 알코올음료 제조업                              50        Close               0.294319
# 기타 정보 서비스업                             50        Close               0.299020
# 텔레비전 방송업                               50        Close               0.304010
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업      50        Close               0.306351
# 운송장비 임대업                               50        Close               0.315514
# 상품 중개업                                 50        Close               0.375198
# 자동차용 엔진 및 자동차 제조업                      50        Close               0.394480
# 전기 및 통신 공사업                            50        Close               0.421724
# 석탄 광업                                  50        Close               0.442399
# 전구 및 조명장치 제조업                          50        Close               0.445317
# 고무제품 제조업                               50        Close               0.449062
# 합성고무 및 플라스틱 물질 제조업                     50        Close               0.472426
# 신탁업 및 집합투자업                            50        Close               0.485688
# Name: 총건수, dtype: float64
